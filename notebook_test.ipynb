# %% [markdown]
# Notebook test

# %%
import numpy as np
import pandas as pd

# %%
my_var = 2
my_var2 = 5
my_var3 = my_var + my_var2

# %%
def math(x: float, y: float, func: str) -> float:
    """Function does a calculation based on the given function"""

    if func == 'add':
        return x + y
    elif func == 'distract':
        return x - y
    elif func == 'multiply':
        return x * y
    elif func == 'divide':
        if y != 0:
            return x / y
        else:
            return 0
    elif func == "modulo":
        return x % y
    else:
        return 0

# %%
var_math = math(5, 4, 'divide')
print(var_math)
# Out:
# 1.25
